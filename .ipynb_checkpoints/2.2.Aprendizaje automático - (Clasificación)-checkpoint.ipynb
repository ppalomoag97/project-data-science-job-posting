# %%
# %reset -f

# %% [markdown]
# ## 03. Aprendizaje automático

# %% [markdown]
# En este apartado, trataremos de predecir la variable categórica 'job_desc', que correponde al puesto de trabajo dentro del mundo del 'DATA' según el grado de experiencia de las diferentes ofertas de trabajo, publicadas en el portal de empleo Glassdoor. Para ello, trataremos de encontrar los predictores y el modelo que mejor expliquen nuestra variable.

# %%
#Librerías a utilizar
import pandas as pd
import numpy as np

# %%
#Importamos el set de datos tratado en el proceso anterior '02. Limpieza y manipulación de datos'
jb = pd.read_csv('./dataset/Cleaned_job_position_CLASSIFICATION.csv')

# %% [markdown]
# Las categorías que trataremos de clasificar serán las siguientes:

# %%
jb.job_desc.value_counts()
# Out:
# job_desc
# data scientist           374
# data engineer             51
# senior data scientist     45
# data analyst              36
# ml engineer               23
# senior data analyst       20
# computer scientist        14
# senior ml engineer         9
# Name: count, dtype: int64

# %% [markdown]
# #### Conversión de variables categóricas a numéricas.

# %% [markdown]
# Actualmente disponemos de 5 columnas categóricas que tenemos que transformar en numéricas para poder incluirlas en el entrenamiento de nuestro modelo de árbol de decisión y ver si son determinantes para explicar nuestra variable de clasificación a predecir, 'job_desc'.

# %%
jb.head()
# Out:
#                       Size       Type of ownership             Sector  \
# 0   1001 to 5000 employees  Nonprofit Organization          Insurance
# 1  5001 to 10000 employees        Company - Public  Business Services
# 2   1001 to 5000 employees       Company - Private  Business Services
# 3    501 to 1000 employees        Company - Public      Manufacturing
# 4      51 to 200 employees       Company - Private  Business Services
#
#                       Revenue  avg_salary  company_age               job_desc  \
# 0    Unknown / Non-Applicable         154           27  senior data scientist
# 1      $1 to $2 billion (USD)         154           52         data scientist
# 2  $100 to $500 million (USD)         154           39         data scientist
# 3  $100 to $500 million (USD)         154           20         data scientist
# 4    Unknown / Non-Applicable         154           22         data scientist
#
#    Python  Excel  Hadoop  Spark  AWS  BI Tools  SQL  Git
# ...

# %%
jb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Size               572 non-null    object
#  1   Type of ownership  572 non-null    object
#  2   Sector             572 non-null    object
#  3   Revenue            572 non-null    object
#  4   avg_salary         572 non-null    int64
#  5   company_age        572 non-null    int64
#  6   job_desc           572 non-null    object
#  7   Python             572 non-null    int64
#  8   Excel              572 non-null    int64
#  9   Hadoop             572 non-null    int64
#  10  Spark              572 non-null    int64
#  11  AWS                572 non-null    int64
#  12  BI Tools           572 non-null    int64
#  13  SQL                572 non-null    int64
#  14  Git                572 non-null    int64
# dtypes: int64(10), object(5)
# memory usage: 67.2+ KB

# %%
columnas_categoricas = jb.select_dtypes(include=['object']).columns
print(columnas_categoricas)
# Out:
# Index(['Size', 'Type of ownership', 'Sector', 'Revenue', 'job_desc'], dtype='object')

# %%
#Librerías que utilizaremos para transformar las varibles categóricas a numéricas
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# Utilizaremos LabelEncoder para las variables que no siguen un orden natural.
#  * job_desc
#  * Type of ownership
#  * Sector

# %%
#Definimos las columnas categóricas
columnas_categoricas_le = columnas_categoricas.drop(['Size', 'Revenue'])

# Inicializar el LabelEncoder
le = LabelEncoder()

# Crear una copia del DataFrame para almacenar los resultados
jb_encoded = jb.copy()

# Crear un diccionario para almacenar el mapeo de cada columna categórica
mapeo_categorias_le = {}

# Convertir cada columna categórica en números y guardar el mapeo
for col in columnas_categoricas_le:
    jb_encoded[col] = le.fit_transform(jb_encoded[col]) + 1  # Agregar 1 para comenzar desde 1
    # Guardar el mapeo en el diccionario
    mapeo_categorias_le[col] = dict(zip(le.classes_, le.transform(le.classes_) + 1))

# Verificar el resultado
print(jb_encoded.head())
# Out:
#                       Size  Type of ownership  Sector  \
# 0   1001 to 5000 employees                  4       8
# 1  5001 to 10000 employees                  2       3
# 2   1001 to 5000 employees                  1       3
# 3    501 to 1000 employees                  2       9
# 4      51 to 200 employees                  1       3
#
#                       Revenue  avg_salary  company_age  job_desc  Python  \
# 0    Unknown / Non-Applicable         154           27         7       6
# 1      $1 to $2 billion (USD)         154           52         4       3
# 2  $100 to $500 million (USD)         154           39         4       3
# 3  $100 to $500 million (USD)         154           20         4       3
# 4    Unknown / Non-Applicable         154           22         4       3
#
#    Excel  Hadoop  Spark  AWS  BI Tools  SQL  Git
# 0      5       5      3    4         3    6    3
# 1      4       1      2    3         1    4    1
# 2      4       2      2    1         2    2    2
# ...

# %%
#Guardamos la transormación de las varibles categóricas en un diccionario
mapeo_categorias_le
# Out:
# {'Type of ownership': {'Company - Private': 1,
#   'Company - Public': 2,
#   'Government': 3,
#   'Nonprofit Organization': 4,
#   'Others': 5,
#   'Subsidiary or Business Segment': 6},
#  'Sector': {'Aerospace & Defense': 1,
#   'Biotech & Pharmaceuticals': 2,
#   'Business Services': 3,
#   'Finance': 4,
#   'Government': 5,
#   'Health Care': 6,
#   'Information Technology': 7,
#   'Insurance': 8,
#   'Manufacturing': 9,
#   'Oil, Gas, Energy & Utilities': 10,
#   'Unknown': 11},
#  'job_desc': {'computer scientist': 1,
#   'data analyst': 2,
#   'data engineer': 3,
#   'data scientist': 4,
#   'ml engineer': 5,
#   'senior data analyst': 6,
#   'senior data scientist': 7,
#   'senior ml engineer': 8}}

# %% [markdown]
# Utilizaremos OrdinalEncoder para las variables que no siguen un orden natural.
#
# * Size
# * Revenue

# %%
# Definir el orden de las categorías manualmente
size_order = [
    'Unknown',
    '1 to 50 employees',
    '51 to 200 employees',
    '201 to 500 employees',
    '501 to 1000 employees',
    '1001 to 5000 employees',
    '5001 to 10000 employees',
    '10000+ employees'
]

revenue_order = [
    'Unknown / Non-Applicable',
    'Less than $1 million (USD)',
    '$1 to $5 million (USD)',
    '$5 to $10 million (USD)',
    '$10 to $25 million (USD)',
    '$25 to $50 million (USD)',
    '$50 to $100 million (USD)',
    '$100 to $500 million (USD)',
    '$500 million to $1 billion (USD)',
    '$1 to $2 billion (USD)',
    '$2 to $5 billion (USD)',
    '$5 to $10 billion (USD)',
    '$10+ billion (USD)'
]

# Inicializar el LabelEncoder
#oe = OrdinalEncoder()

# Crear el OrdinalEncoder con el orden especificado
#encoder = oe(categories=[size_order, revenue_order])

# Aplicar el encoder a las columnas 'Size' y 'Revenue'
#jb[['Size_encoded', 'Revenue_encoded']] = encoder.fit_transform(jb[['Size', 'Revenue']])

# %%
# Crear el OrdinalEncoder con el orden especificado
encoder = OrdinalEncoder(categories=[size_order, revenue_order])

# Aplicar el encoder a las columnas 'Size' y 'Revenue'
jb_encoded[['Size', 'Revenue']] = encoder.fit_transform(jb_encoded[['Size', 'Revenue']]).astype(int)

# Diccionario con el nuevo código y la descripción original
size_mapeo = {idx: categoria for idx, categoria in enumerate(size_order)}
revenue_mapeo = {idx: categoria for idx, categoria in enumerate(revenue_order)}

# Almacenar ambos en un diccionario general
mapeo_categorias_oe = {
    'Size': size_mapeo,
    'Revenue': revenue_mapeo
}
# Verificar el resultado
print(jb_encoded.head())
# Out:
#    Size  Type of ownership  Sector  Revenue  avg_salary  company_age  \
# 0     5                  4       8        0         154           27
# 1     6                  2       3        9         154           52
# 2     5                  1       3        7         154           39
# 3     4                  2       9        7         154           20
# 4     2                  1       3        0         154           22
#
#    job_desc  Python  Excel  Hadoop  Spark  AWS  BI Tools  SQL  Git
# 0         7       6      5       5      3    4         3    6    3
# 1         4       3      4       1      2    3         1    4    1
# 2         4       3      4       2      2    1         2    2    2
# 3         4       3      4       2      2    3         1    4    3
# 4         4       3      4       1      1    2         2    2    2

# %%
mapeo_categorias_oe
# Out:
# {'Size': {0: 'Unknown',
#   1: '1 to 50 employees',
#   2: '51 to 200 employees',
#   3: '201 to 500 employees',
#   4: '501 to 1000 employees',
#   5: '1001 to 5000 employees',
#   6: '5001 to 10000 employees',
#   7: '10000+ employees'},
#  'Revenue': {0: 'Unknown / Non-Applicable',
#   1: 'Less than $1 million (USD)',
#   2: '$1 to $5 million (USD)',
#   3: '$5 to $10 million (USD)',
#   4: '$10 to $25 million (USD)',
#   5: '$25 to $50 million (USD)',
#   6: '$50 to $100 million (USD)',
#   7: '$100 to $500 million (USD)',
#   8: '$500 million to $1 billion (USD)',
#   9: '$1 to $2 billion (USD)',
#   10: '$2 to $5 billion (USD)',
#   11: '$5 to $10 billion (USD)',
#   12: '$10+ billion (USD)'}}

# %%
jb_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Size               572 non-null    int64
#  1   Type of ownership  572 non-null    int64
#  2   Sector             572 non-null    int64
#  3   Revenue            572 non-null    int64
#  4   avg_salary         572 non-null    int64
#  5   company_age        572 non-null    int64
#  6   job_desc           572 non-null    int64
#  7   Python             572 non-null    int64
#  8   Excel              572 non-null    int64
#  9   Hadoop             572 non-null    int64
#  10  Spark              572 non-null    int64
#  11  AWS                572 non-null    int64
#  12  BI Tools           572 non-null    int64
#  13  SQL                572 non-null    int64
#  14  Git                572 non-null    int64
# dtypes: int64(15)
# memory usage: 67.2 KB

# %% [markdown]
# ## Modelado, predicción y evaluación

# %% [markdown]
# En este apartado, definiremos cuatro modelos: Árbol de decisión, Regresión logística, Random Forest, y Gradient Boosting. Aplicaremos técnicas de validación cruzada (K-folds) para cada uno de los modelos y así poder obtener una evaluación promedio.
#
# Posteriormente, realizaremos un ajuste de hiperparámetros con GridSearchCV para obtener los mejores parámetros de cada modelo.
#
# Entrenaremos los modelos con los mismos datos de entrenamiento, tanto datos originales como datos estadarizados, para finalmente poder comparar los resultados y hacer la elección del modelo con el que mejor métricas obtengamos.
#
# En definitiva, resumimos los pasos a seguir:
#
#          1 - Creación del modelo
#
#          2 - Validación Cruzada (K-folds)
#
#          3 - Ajuste de hiperparámetros
#
#          4 - Entrenamiento (con y sin Estandarización)
#
#          5 - Evaluación y Comparación de Resultados

# %%
#Definimos una semilla para poder replicar el proceso 
seed=17

# %% [markdown]
# ### 1. División del set de datos en conjuntos de train (70%) y de test (30%).

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %% [markdown]
# En este apartado, dividiremos nuestro set de datos en 70% para entrenamiento y 30% para test. Escogemos un 30% en lugar de un 20% debido a que tenemos pocos datos.
# Además, estandarizaremos nuestros datos para poder comprobar como afecta al rendimiento de nuestros modelos.

# %%
#Separamos nuestra variables características de nuestra variable objetivo
X = jb_encoded.drop(columns=['job_desc'])
y = jb_encoded['job_desc']

# Dividimos los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

# Inicializamos el RobustScaler para el estadarizado de datos
scaler = RobustScaler()

# Ajustamos el scaler en los datos de entrenamiento y prueba
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# (400, 14) (172, 14) (400,) (172,)

# %%
#Definimos una función para la matriz de confusión como método de evaluación visual de cada modelo
import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np

def plot_confusion_matrix(y, y_pred):
    # Extraer el mapeo de etiquetas y sus índices
    mapeo = mapeo_categorias_le['job_desc']
    
    # Invertir el diccionario para mapear índices a etiquetas
    etiquetas = {v: k for k, v in mapeo.items()}
    
    # Generar la matriz de confusión
    cm = metrics.confusion_matrix(y, y_pred)
    
    # Configurar la figura y el tamaño
    plt.figure(figsize=(6, 4))
    
    # Mostrar la matriz de confusión como una imagen de colores
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Matriz de Confusión')
    plt.colorbar()  # Mostrar la barra de colores que representa los valores
    
    # Configurar etiquetas de los ejes x e y usando el diccionario invertido
    classes = sorted(etiquetas.keys())
    tick_marks = np.arange(len(classes))
    
    plt.xticks(tick_marks, [etiquetas[i] for i in classes], rotation=45)
    plt.yticks(tick_marks, [etiquetas[i] for i in classes])
    
    # Agregar números como anotaciones de texto en cada celda
    threshold = cm.max() / 2.  # Umbral para decidir el color del texto
    for i, j in np.ndindex(cm.shape):
        plt.text(j, i, format(cm[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > threshold else "black")
    
    # Ajustar el diseño para mejorar la legibilidad
    plt.tight_layout()
    
    # Etiquetas de los ejes y título
    plt.ylabel('Etiqueta Verdadera')
    plt.xlabel('Etiqueta Predicha')
    plt.show()

# %% [markdown]
# ## Regresión logística

# %% [markdown]
# En primer lugar, entrenaremos un modelo de regresión logística con todas las variables de nuestro set de datos. En este caso, dado que este modelo es sensible a la escala de las características, realizaremos pruebas con datos originales y con datos escalados.

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Inicializamos el modelo de regresión logística
logistic_regression_model = LogisticRegression(random_state=seed, max_iter=8000)

# Ajustamos el modelo a los datos de entrenamiento
logistic_regression_model.fit(X_train, y_train)

# Calculamos el rendimiento del modelo de regresión logística en el conjunto de entrenamiento
score_logistic = logistic_regression_model.score(X_train, y_train)
print(f"Rendimiento del modelo de regresión logística en el conjunto de entrenamiento: {score_logistic:.4f}")

# Predecimos las etiquetas en el conjunto de prueba
y_pred_lr = logistic_regression_model.predict(X_test)

# Mostramos la matriz de confusión
#conf_matrix = plot_confusion_matrix(y_test, y_pred_lr)
#print("Matriz de confusión:")
#print(conf_matrix)

# Calculamos la puntuación de precisión
accuracy_lr = accuracy_score(y_test, y_pred_lr)
print(f"Precisión del modelo: {accuracy_lr}")

# Imprimimos un informe de clasificación detallado
print("Informe de clasificación:")
print(classification_report(y_test, y_pred_lr))
# Out:
# Rendimiento del modelo de regresión logística en el conjunto de entrenamiento: 0.9775
# Precisión del modelo: 0.8837209302325582
# Informe de clasificación:
#               precision    recall  f1-score   support
#
#            1       0.29      0.67      0.40         3
#            2       0.91      0.91      0.91        11
#            3       0.76      0.73      0.74        22
#            4       0.94      0.99      0.97       102
#            5       0.60      0.30      0.40        10
#            6       1.00      0.57      0.73         7
#            7       1.00      0.93      0.96        14
#            8       0.75      1.00      0.86         3
#
#     accuracy                           0.88       172
#    macro avg       0.78      0.76      0.75       172
# weighted avg       0.89      0.88      0.88       172

# %% [markdown]
# #### Con datos escalados

# %%
# Ajustamos el modelo a los datos de entrenamiento escalados
logistic_regression_model.fit(X_train_scaled, y_train)

# Calculamos el rendimiento del modelo de regresión logística en el conjunto de entrenamiento escalado
score_logistic_scaled = logistic_regression_model.score(X_train_scaled, y_train)
print(f"Rendimiento del modelo de regresión logística en el conjunto de entrenamiento: {score_logistic_scaled:.4f}")

# Predecimos las etiquetas en el conjunto de prueba escalados
y_pred_lr_scaled = logistic_regression_model.predict(X_test_scaled)

# Mostramos la matriz de confusión
#conf_matrix = plot_confusion_matrix(y_test, y_pred_lr_scaled)
#print("Matriz de confusión:")
#print(conf_matrix)

# Calculamos la puntuación de precisión
accuracy_lr_scaled = accuracy_score(y_test, y_pred_lr_scaled)
print(f"Precisión del modelo: {accuracy_lr_scaled}")

# Imprimimos un informe de clasificación detallado
print("Informe de clasificación:")
print(classification_report(y_test, y_pred_lr_scaled))
# Out:
# Rendimiento del modelo de regresión logística en el conjunto de entrenamiento: 0.9625
# Precisión del modelo: 0.9011627906976745
# Informe de clasificación:
#               precision    recall  f1-score   support
#
#            1       0.29      0.67      0.40         3
#            2       1.00      0.91      0.95        11
#            3       0.81      0.77      0.79        22
#            4       0.93      1.00      0.96       102
#            5       1.00      0.40      0.57        10
#            6       1.00      0.57      0.73         7
#            7       1.00      0.93      0.96        14
#            8       1.00      1.00      1.00         3
#
#     accuracy                           0.90       172
#    macro avg       0.88      0.78      0.80       172
# weighted avg       0.92      0.90      0.90       172

# %% [markdown]
# ##### Análisis de características

# %% [markdown]
# ## Árbol de decisión

# %% [markdown]
# En segundo lugar, entrenaremos un modelo de árbol de decisión de clasificación con todas las variables de nuestro set de datos. En este caso no entrenaremos el modelo de datos con datos escalados dado que el árbol de decisión no es sensible a ellos.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %% [markdown]
# #### Con datos originales

# %%
# Inicializamos el modelo de árbol de decisión
decision_tree_model= DecisionTreeClassifier(random_state=seed)

# Ajustamos el modelo a los datos de entrenamiento
decision_tree_model.fit(X_train, y_train)

# Calculamos y mostramos el rendimiento del modelo de árbol de decisión en el conjunto de entrenamiento
score_tree = decision_tree_model.score(X_train, y_train)
print(f"Rendimiento del modelo de árbol de decisión en el conjunto de entrenamiento: {score_tree:.4f}")

# Predecimos las etiquetas en el conjunto de prueba
y_pred = decision_tree_model.predict(X_test)

# Mostramos la matriz de confusión
#conf_matrix = plot_confusion_matrix(y_test, y_pred)
#print("Matriz de confusión:")
#print(conf_matrix)

# Calculamos la puntuación de precisión
accuracy = accuracy_score(y_test, y_pred)
print(f"Precisión del modelo: {accuracy}")

# Imprimimos un informe de clasificación detallado
print("Informe de clasificación:")
print(classification_report(y_test, y_pred))
# Out:
# Rendimiento del modelo de árbol de decisión en el conjunto de entrenamiento: 1.0000
# Precisión del modelo: 0.877906976744186
# Informe de clasificación:
#               precision    recall  f1-score   support
#
#            1       0.14      0.33      0.20         3
#            2       0.85      1.00      0.92        11
#            3       0.72      0.59      0.65        22
#            4       0.99      0.99      0.99       102
#            5       0.38      0.30      0.33        10
#            6       1.00      0.71      0.83         7
#            7       1.00      1.00      1.00        14
#            8       0.60      1.00      0.75         3
#
#     accuracy                           0.88       172
#    macro avg       0.71      0.74      0.71       172
# weighted avg       0.89      0.88      0.88       172

# %%
# Paso 1: Calcular la mediana y el IQR en datos originales
median_orig = np.median(X_train, axis=0)
q75_orig, q25_orig = np.percentile(X_train, [75 ,25], axis=0)
iqr_orig = q75_orig - q25_orig

print("Datos Originales:")
print("Mediana de cada característica en X_train:", median_orig)
print("IQR (Rango Intercuartílico) de cada característica en X_train:", iqr_orig)
# Out:
# Datos Originales:
# Mediana de cada característica en X_train: [  3.   1.   7.   5. 114.  17.   4.   3.   2.   2.   2.   2.   3.   2.]
# IQR (Rango Intercuartílico) de cada característica en X_train: [ 3.  1.  4.  8. 33. 34.  2.  2.  1.  2.  2.  1.  2.  2.]

# %% [markdown]
# #### Con datos escalados

# %%
# Ajustamos el modelo a los datos de entrenamiento escalados
decision_tree_model.fit(X_train_scaled, y_train)

# Calculamos y mostramos el rendimiento del modelo de árbol de decisión en el conjunto de entrenamiento con datos escalados
score_tree_scaled = decision_tree_model.score(X_train_scaled, y_train)
print(f"Rendimiento del modelo de árbol de decisión en el conjunto de entrenamiento: {score_tree_scaled:.4f}")

# Predecimos las etiquetas en el conjunto de prueba escalados
y_pred_tree_scaled = decision_tree_model.predict(X_test_scaled)

# Mostramos la matriz de confusión
#conf_matrix = plot_confusion_matrix(y_test, y_pred_tree_scaled)
#print("Matriz de confusión:")
#print(conf_matrix)

# Calculamos la puntuación de precisión
accuracy_scaled = accuracy_score(y_test, y_pred_tree_scaled)
print(f"Precisión del modelo: {accuracy_scaled}")

# Imprimimos un informe de clasificación detallado
print("Informe de clasificación:")
print(classification_report(y_test, y_pred_tree_scaled))
# Out:
# Rendimiento del modelo de árbol de decisión en el conjunto de entrenamiento: 1.0000
# Precisión del modelo: 0.877906976744186
# Informe de clasificación:
#               precision    recall  f1-score   support
#
#            1       0.14      0.33      0.20         3
#            2       0.85      1.00      0.92        11
#            3       0.72      0.59      0.65        22
#            4       0.99      0.99      0.99       102
#            5       0.38      0.30      0.33        10
#            6       1.00      0.71      0.83         7
#            7       1.00      1.00      1.00        14
#            8       0.60      1.00      0.75         3
#
#     accuracy                           0.88       172
#    macro avg       0.71      0.74      0.71       172
# weighted avg       0.89      0.88      0.88       172

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns

# %%
# Inicializamos el modelo de Random Forest
random_forest_model = RandomForestClassifier(random_state=seed)

# Ajustamos el modelo a los datos de entrenamiento
random_forest_model.fit(X_train, y_train)

# Calculamos el rendimiento del modelo de Random Forest en el conjunto de entrenamiento
score_rf = random_forest_model.score(X_train, y_train)
print(f"Rendimiento del modelo de Random Forest en el conjunto de entrenamiento: {score_rf:.4f}")

# Predecimos las etiquetas en el conjunto de prueba
y_pred_rf = random_forest_model.predict(X_test)

# Mostramos la matriz de confusión
#conf_matrix = plot_confusion_matrix(y_test, y_pred_rf)
#print("Matriz de confusión:")
#print(conf_matrix)

# Calculamos la puntuación de precisión
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f"Precisión del modelo de Random Forest: {accuracy_rf:.4f}")

# Imprimimos un informe de clasificación detallado
print("Informe de clasificación para Random Forest:")
print(classification_report(y_test, y_pred_rf))
# Out:
# Rendimiento del modelo de Random Forest en el conjunto de entrenamiento: 1.0000
# Precisión del modelo de Random Forest: 0.9360
# Informe de clasificación para Random Forest:
#               precision    recall  f1-score   support
#
#            1       1.00      0.67      0.80         3
#            2       1.00      1.00      1.00        11
#            3       0.74      0.91      0.82        22
#            4       0.98      1.00      0.99       102
#            5       0.60      0.30      0.40        10
#            6       1.00      1.00      1.00         7
#            7       1.00      1.00      1.00        14
#            8       1.00      0.67      0.80         3
#
#     accuracy                           0.94       172
#    macro avg       0.92      0.82      0.85       172
# weighted avg       0.93      0.94      0.93       172

# %% [markdown]
# Ajuste hiperparámetros

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Configurar los hiperparámetros para la búsqueda en cuadrícula
param_grid = {
    'n_estimators': [50, 100, 150, 200],   # Número de árboles
    'max_depth': [None, 10, 20, 30],       # Profundidad máxima de los árboles
    'min_samples_split': [2, 5, 10],        # Número mínimo de muestras para dividir un nodo
    'min_samples_leaf': [1, 2, 4]           # Número mínimo de muestras en una hoja
}

# Configurar la búsqueda en cuadrícula
grid_search = GridSearchCV(estimator=random_forest_model, param_grid=param_grid, 
                           cv=5, n_jobs=-1, verbose=2, scoring='accuracy')

# Ejecutar GridSearchCV en el conjunto de entrenamiento
grid_search.fit(X_train, y_train)

# Mostrar los mejores parámetros y la mejor puntuación
print("Mejores parámetros encontrados:")
print(grid_search.best_params_)
print("Mejor puntuación de validación cruzada:")
print(grid_search.best_score_)

# Usar el mejor modelo para hacer predicciones en el conjunto de prueba
best_rf = grid_search.best_estimator_
y_pred = best_rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Precisión en el conjunto de prueba: {accuracy:.4f}')
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.3s
# ...

# %% [markdown]
# ### Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
# Inicializamos el modelo de Gradient Boosting
gradient_boosting_model = GradientBoostingClassifier(random_state=seed)

# Ajustamos el modelo a los datos de entrenamiento
gradient_boosting_model.fit(X_train, y_train)

# Calculamos el rendimiento del modelo de Gradient Boosting en el conjunto de entrenamiento
score_gb = gradient_boosting_model.score(X_train, y_train)
print(f"Rendimiento del modelo de Gradient Boosting en el conjunto de entrenamiento: {score_gb:.4f}")

# Predecimos las etiquetas en el conjunto de prueba
y_pred_gb = gradient_boosting_model.predict(X_test)

# Mostramos la matriz de confusión
#conf_matrix = plot_confusion_matrix(y_test, y_pred_gb)
#print("Matriz de confusión:")
#print(conf_matrix)

# Calculamos la puntuación de precisión
accuracy_gb = accuracy_score(y_test, y_pred_gb)
print(f"Precisión del modelo de Gradient Boosting: {accuracy_gb:.4f}")

# Imprimimos un informe de clasificación detallado
print("Informe de clasificación para Gradient Boosting:")
print(classification_report(y_test, y_pred_gb))
# Out:
# Rendimiento del modelo de Gradient Boosting en el conjunto de entrenamiento: 1.0000
# Precisión del modelo de Gradient Boosting: 0.9012
# Informe de clasificación para Gradient Boosting:
#               precision    recall  f1-score   support
#
#            1       0.33      0.67      0.44         3
#            2       1.00      0.91      0.95        11
#            3       0.74      0.77      0.76        22
#            4       0.95      1.00      0.98       102
#            5       0.60      0.30      0.40        10
#            6       1.00      1.00      1.00         7
#            7       1.00      0.86      0.92        14
#            8       1.00      0.67      0.80         3
#
#     accuracy                           0.90       172
#    macro avg       0.83      0.77      0.78       172
# weighted avg       0.90      0.90      0.90       172

# %%
len(y)
# Out:
# 572

# %% [markdown]
# ### Validación cruzada

# %%
from sklearn import model_selection

# %%
# Inicializar una matriz para almacenar los puntajes de precisión para cada pliegue y modelo
acc = np.zeros((5, 4))  # 5 pliegues, 4 modelos

# Crear un objeto KFold para validación cruzada de 5-fold
kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=0)

# Contador de bucle
i = 0

# Iterar sobre cada pliegue definido por KFold
for train_index, test_index in kf.split(X):
    # Dividir los datos en conjuntos de entrenamiento y prueba basados en el pliegue actual
    X_train, X_val = X.iloc[train_index], X.iloc[test_index]
    y_train, y_val = y.iloc[train_index], y.iloc[test_index]
    
    # Inicializar clasificadores
    rl = LogisticRegression(max_iter=8000)
    dt = DecisionTreeClassifier()
    rf = RandomForestClassifier()
    gb = GradientBoostingClassifier()  # Árbol de decisión
    
    # Entrenar cada clasificador en el conjunto de entrenamiento
    rl.fit(X_train, y_train)
    dt.fit(X_train, y_train)
    rf.fit(X_train, y_train)
    gb.fit(X_train, y_train)
    
    # Realizar predicciones en el conjunto de prueba
    yhat_rl = rl.predict(X_test)
    yhat_dt = dt.predict(X_test)
    yhat_rf = rf.predict(X_test)
    yhat_gb = gb.predict(X_test)
    
    # Calcular y almacenar la precisión para cada clasificador
    acc[i][0] = metrics.accuracy_score(yhat_rl, y_test)
    acc[i][1] = metrics.accuracy_score(yhat_dt, y_test)
    acc[i][2] = metrics.accuracy_score(yhat_rf, y_test)
    acc[i][3] = metrics.accuracy_score(yhat_gb, y_test)
    
    # Incrementar el contador del bucle
    i += 1

# Visualizar los puntajes de precisión como un gráfico de caja para cada clasificador
plt.boxplot(acc)

# Superponer los puntajes individuales de precisión como puntos rojos para una mejor visualización
for i in range(4):
    xderiv = (i+1) * np.ones(acc[:, i].shape) + (np.random.rand(5,) - 0.5) * 0.1
    plt.plot(xderiv, acc[:, i], 'ro', alpha=0.3)

# Configurar las etiquetas para cada clasificador en el eje x
ax = plt.gca()
ax.set_xticklabels(['Regresión Logística', 'Árbol Decisión', 'Random Forest', 'Gradient Boosting'])

plt.xlabel('Tipo de Clasificador')
plt.ylabel('Precisión')
plt.title('Resultados de Validación Cruzada de 5-Fold')

plt.show()

# %% [markdown]
# La validación cruzada es un método fundamental en el aprendizaje automático para evaluar cómo los resultados de un análisis estadístico se generalizarán a un conjunto de datos independiente. Es especialmente útil en escenarios donde el objetivo es predecir, y se desea estimar cuán precisamente un modelo predictivo funcionará en la práctica.

# %% [markdown]
# ### Validación de hiperparámetros

# %% [markdown]
# REGRESIÓN LOGÍSTICA

# %%
# Supongamos que X y y son tus datos de entrada y salida.
# X = ...
# y = ...

# Configurar una validación cruzada de 10 pliegues.
kf = model_selection.KFold(n_splits=10, shuffle=True, random_state=0)
kf.get_n_splits()

# Preparar el rango de valores para el parámetro de regularización C.
C = np.arange(0.01, 1.01, 0.11)  # Ajustar el rango según tus necesidades.

# Inicializar un array para almacenar las puntuaciones de precisión para diferentes pliegues y valores de C.
acc = np.zeros((10, len(C)))  # 10 para los pliegues, len(C) para el rango de C.
i = 0

# Realizar la validación cruzada.
for train_index, val_index in kf.split(X):
    # Dividir los datos en conjuntos de entrenamiento y validación para el pliegue actual.
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]
    
    j = 0
    # Evaluar el modelo para cada valor de C.
    for c in C:
        # Inicializar y entrenar el clasificador de regresión logística con el valor de C actual.
        lr = LogisticRegression(C=c, solver='liblinear')  # Usar 'liblinear' para L1 y L2.
        lr.fit(X_train, y_train)  # Entrenar el modelo.
        yhat = lr.predict(X_val)  # Predecir los resultados del conjunto de validación.
        
        # Calcular y almacenar la precisión para el pliegue y valor de C actuales.
        acc[i][j] = metrics.accuracy_score(y_val, yhat)
        j += 1
    i += 1

# Graficar la precisión para cada valor de C como un boxplot para mostrar la distribución.
plt.boxplot(acc, labels=C)
# Superponer las puntuaciones de precisión individuales para cada valor de C.
for i in range(len(C)):
    xderiv = (i + 1) * np.ones(acc[:, i].shape) + (np.random.rand(10,) - 0.5) * 0.1
    plt.plot(xderiv, acc[:, i], 'ro', alpha=0.3)  # 'ro' indica marcadores de círculo rojo.

# Establecer los límites para el eje y para centrarse en el rango de interés.
plt.ylim((0.80, 1))

# Configurar el tamaño de la figura para una mejor visibilidad.
fig = plt.gcf()
fig.set_size_inches(9, 5)

# Añadir etiquetas y título para mayor claridad.
plt.xlabel('Valor de C')
plt.ylabel('Precisión')
plt.title('Precisión de la Regresión Logística para Diferentes Valores de C')

plt.show()

# %%
# Calcular la precisión media a través de todos los pliegues para cada valor de C.
macc = np.mean(acc, axis=0)

# Encontrar el índice del valor de C que produce la mayor precisión media.
idx = np.argmax(macc)

# Imprimir el valor de C y la precisión correspondiente.
print(f'Valor de C con mayor precisión media: {C[idx]}')
print(f'Precisión media: {macc[idx]:.4f}')
# Out:
# Valor de C con mayor precisión media: 1.0
# Precisión media: 0.9003

# %% [markdown]
# ÁRBOL DECISIÓN

# %%
# Set up a 10-fold cross-validation. This will split our data into 10 parts.
kf = model_selection.KFold(n_splits=10, shuffle=True, random_state=0)
kf.get_n_splits()

# Prepare to search for the best complexity parameter from the given range.
C = np.arange(2, 20)  # Range of model complexities to evaluate.

# Initialize an array to store accuracy scores for different folds and complexities.
acc = np.zeros((10, len(C)))  # 10 for folds, 18 for the range of complexities.
i = 0
# Perform cross-validation.
for train_index, val_index in kf.split(X):
    # Split the data into training and validation sets for the current fold.
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]
    
    j = 0
    # Evaluate the model for each complexity level.
    for c in C:
        # Initialize and train a decision tree classifier at the current complexity level.
        dt = tree.DecisionTreeClassifier(min_samples_leaf=1, max_depth=c)
        dt.fit(X_train, y_train.to_numpy())  # Train the model.
        yhat = dt.predict(X_val)  # Predict validation set outcomes.
        
        # Calculate and store the accuracy for the current fold and complexity.
        acc[i][j] = metrics.accuracy_score(yhat, y_val)
        j += 1
    i += 1

# Plot the accuracy for each complexity as a boxplot to show the distribution.
plt.boxplot(acc)
# Overlay the individual accuracy scores for each complexity level.
for i in range(len(C)):
    xderiv = (i+1)*np.ones(acc[:,i].shape) + (np.random.rand(10,)-0.5)*0.1
    plt.plot(xderiv, acc[:,i], 'ro', alpha=0.3)  # 'ro' indicates red circle markers.

# Set the limits for the y-axis to focus on the range of interest.
plt.ylim((0.80, 1))

# Configure the figure size for better visibility.
fig = plt.gcf()
fig.set_size_inches(9, 5)

# %%
# Calculate the mean accuracy across all cross-validation folds for each complexity level.
macc = np.mean(acc, axis=0)

# Find the index of the complexity level that yields the highest mean accuracy.
idx = np.argmax(macc)

# Print the complexity level (adding 1 because the index starts at 0) and the corresponding accuracy.
# This tells us which model (in terms of complexity) performed the best on average across the cross-validation folds.
print('Complexity: ' + str(idx+1) + ' with accuracy: ' + str(macc[idx]))
# Out:
# Complexity: 8 with accuracy: 0.9318511796733212

# %% [markdown]
# AJUSTANDO HIPERPARÁMETROS DE ÁRBOL DE DECISIÓN ME DA LO MISMO QUE ME DABA RANDOM FOREST.

# %% [markdown]
# RANDOM FOREST

# %%
#Configurar una validación cruzada de 10 pliegues.
kf = model_selection.KFold(n_splits=10, shuffle=True, random_state=0)
kf.get_n_splits()

# Preparar el rango de valores para el parámetro de número de árboles en el Random Forest.
n_estimators = np.arange(10, 110, 10)  # Rango de número de árboles a evaluar.

# Inicializar un array para almacenar las puntuaciones de precisión para diferentes pliegues y números de árboles.
acc = np.zeros((10, len(n_estimators)))  # 10 para los pliegues, len(n_estimators) para el rango de números de árboles.
i = 0

# Realizar la validación cruzada.
for train_index, val_index in kf.split(X):
    # Dividir los datos en conjuntos de entrenamiento y validación para el pliegue actual.
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]
    
    j = 0
    # Evaluar el modelo para cada número de árboles.
    for n in n_estimators:
        # Inicializar y entrenar el clasificador Random Forest con el número de árboles actual.
        rf = RandomForestClassifier(n_estimators=n, random_state=0)
        rf.fit(X_train, y_train)  # Entrenar el modelo.
        yhat = rf.predict(X_val)  # Predecir los resultados del conjunto de validación.
        
        # Calcular y almacenar la precisión para el pliegue y número de árboles actuales.
        acc[i][j] = metrics.accuracy_score(y_val, yhat)
        j += 1
    i += 1

# Calcular la precisión media a través de todos los pliegues para cada número de árboles.
macc = np.mean(acc, axis=0)

# Encontrar el índice del número de árboles que produce la mayor precisión media.
idx = np.argmax(macc)

# Imprimir el número de árboles y la precisión correspondiente.
print(f'Número de árboles con mayor precisión media: {n_estimators[idx]}')
print(f'Precisión media: {macc[idx]:.4f}')

# Graficar la precisión para cada número de árboles como un boxplot para mostrar la distribución.
plt.boxplot(acc, labels=n_estimators)
# Superponer las puntuaciones de precisión individuales para cada número de árboles.
for i in range(len(n_estimators)):
    xderiv = (i + 1) * np.ones(acc[:, i].shape) + (np.random.rand(10,) - 0.5) * 0.1
    plt.plot(xderiv, acc[:, i], 'ro', alpha=0.3)  # 'ro' indica marcadores de círculo rojo.

# Establecer los límites para el eje y para centrarse en el rango de interés.
plt.ylim((0.80, 1))

# Configurar el tamaño de la figura para una mejor visibilidad.
fig = plt.gcf()
fig.set_size_inches(9, 5)

# Añadir etiquetas y título para mayor claridad.
plt.xlabel('Número de árboles')
plt.ylabel('Precisión')
plt.title('Precisión del Random Forest para Diferentes Números de Árboles')

plt.show()
# Out:
# Número de árboles con mayor precisión media: 80
# Precisión media: 0.9476

# %%
from sklearn.model_selection import GridSearchCV

# Dividir el conjunto de datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# Definir el modelo Random Forest
rf = RandomForestClassifier(random_state=0)

# Configurar los hiperparámetros para la búsqueda en cuadrícula
param_grid = {
    'n_estimators': [50, 100, 150, 200],   # Número de árboles
    'max_depth': [None, 10, 20, 30],       # Profundidad máxima de los árboles
    'min_samples_split': [2, 5, 10],        # Número mínimo de muestras para dividir un nodo
    'min_samples_leaf': [1, 2, 4]           # Número mínimo de muestras en una hoja
}

# Configurar la búsqueda en cuadrícula
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, 
                           cv=5, n_jobs=-1, verbose=2, scoring='accuracy')

# Ejecutar GridSearchCV en el conjunto de entrenamiento
grid_search.fit(X_train, y_train)

# Mostrar los mejores parámetros y la mejor puntuación
print("Mejores parámetros encontrados:")
print(grid_search.best_params_)
print("Mejor puntuación de validación cruzada:")
print(grid_search.best_score_)

# Usar el mejor modelo para hacer predicciones en el conjunto de prueba
best_rf = grid_search.best_estimator_
y_pred = best_rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Precisión en el conjunto de prueba: {accuracy:.4f}')

# %% [markdown]
# DEFINIMOS LOS PARÁMETROS EN EL MODELO OPTIMIZADO

# %%
# Initialize a decision tree classifier with the optimal complexity found previously.
# 'min_samples_leaf=1' means each leaf node must contain at least 1 sample.
# 'max_depth=idx+1' sets the depth of the tree to the best complexity level identified from cross-validation.
dt = tree.DecisionTreeClassifier(max_depth=7)

# Fit the decision tree model to the training data.
# This step involves the model learning from the training data, using the optimal complexity we identified.
dt.fit(X_train, y_train)

# Use the trained model to predict the labels of the out-of-sample data.
yhat = dt.predict(X_test)

# Calculate and print the accuracy of the model on the out-of-sample data.
# This gives us an estimate of how well our model can generalize to new data,
# which is crucial for understanding its performance in real-world scenarios.
print(metrics.accuracy_score(yhat, y_test))
# Out:
# 0.9883720930232558

# %%
# Configurar una validación cruzada de 10 pliegues.
kf = model_selection.KFold(n_splits=10, shuffle=True, random_state=0)
kf.get_n_splits()

# Preparar el rango de valores para el parámetro de número de estimadores en Gradient Boosting.
n_estimators = np.arange(50, 550, 50)  # Rango de número de estimadores a evaluar.

# Inicializar un array para almacenar las puntuaciones de precisión para diferentes pliegues y números de estimadores.
acc = np.zeros((10, len(n_estimators)))  # 10 para los pliegues, len(n_estimators) para el rango de números de estimadores.
i = 0

# Realizar la validación cruzada.
for train_index, val_index in kf.split(X):
    # Dividir los datos en conjuntos de entrenamiento y validación para el pliegue actual.
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]
    
    j = 0
    # Evaluar el modelo para cada número de estimadores.
    for n in n_estimators:
        # Inicializar y entrenar el clasificador Gradient Boosting con el número de estimadores actual.
        gb = GradientBoostingClassifier(n_estimators=n, random_state=0)
        gb.fit(X_train, y_train)  # Entrenar el modelo.
        yhat = gb.predict(X_val)  # Predecir los resultados del conjunto de validación.
        
        # Calcular y almacenar la precisión para el pliegue y número de estimadores actuales.
        acc[i][j] = metrics.accuracy_score(y_val, yhat)
        j += 1
    i += 1

# Calcular la precisión media a través de todos los pliegues para cada número de estimadores.
macc = np.mean(acc, axis=0)

# Encontrar el índice del número de estimadores que produce la mayor precisión media.
idx = np.argmax(macc)

# Imprimir el número de estimadores y la precisión correspondiente.
print(f'Número de estimadores con mayor precisión media: {n_estimators[idx]}')
print(f'Precisión media: {macc[idx]:.4f}')

# Graficar la precisión para cada número de estimadores como un boxplot para mostrar la distribución.
plt.boxplot(acc, labels=n_estimators)
# Superponer las puntuaciones de precisión individuales para cada número de estimadores.
for i in range(len(n_estimators)):
    xderiv = (i + 1) * np.ones(acc[:, i].shape) + (np.random.rand(10,) - 0.5) * 0.1
    plt.plot(xderiv, acc[:, i], 'ro', alpha=0.3)  # 'ro' indica marcadores de círculo rojo.

# Establecer los límites para el eje y para centrarse en el rango de interés.
plt.ylim((0.80, 1))

# Configurar el tamaño de la figura para una mejor visibilidad.
fig = plt.gcf()
fig.set_size_inches(9, 5)

# Añadir etiquetas y título para mayor claridad.
plt.xlabel('Número de estimadores')
plt.ylabel('Precisión')
plt.title('Precisión del Gradient Boosting para Diferentes Números de Estimadores')

plt.show()
# Out:
# Número de estimadores con mayor precisión media: 300
# Precisión media: 0.9458

# %% [markdown]
# ## Análisis de características

# %% [markdown]
# Veamos la importancia de cada característica

# %%
# Obtenenemos la importantcia de las características para cada modelo

#Dado que regresión logística tenemos un conjunto de coeficientes por cada clase, promediamos los coeficientes para cada característica.
importances_lr = np.mean(np.abs(logistic_regression_model.coef_), axis=0)
importances_dt = decision_tree_model.feature_importances_
importances_rt = random_forest_model.feature_importances_
importances_gb = gradient_boosting_model.feature_importances_

# Creamos un dataframe
feature_importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance LR': importances_lr,
    'Importance DT': importances_dt,
    'Importance RT': importances_rt,
    'Importance GB': importances_gb    
}).sort_values(by='Importance LR', ascending=False)

# Establecer el tamaño del gráfico
plt.figure(figsize=(14, 8))

# Crear el gráfico de barras usando Seaborn
ax = sns.barplot(x="Feature", y="Importance", hue="Model", data=melted_df, palette="Set2")

# Rotar las etiquetas del eje x para que no se superpongan
plt.xticks(rotation=90)

# Agregar título y etiquetas
plt.title('Comparación de Importancia de Características entre Modelos')
plt.xlabel('Características')
plt.ylabel('Importancia')

# Mostrar la leyenda
plt.legend(title='Modelo')

# Agregar los números encima de cada barra, colocándolos bien arriba
for p in ax.patches:
    height = p.get_height()  # Altura de la barra
    if height > 0:  # Evitar valores negativos o ceros
        ax.annotate(format(height, '.4f'),  # Formato para los números
                    (p.get_x() + p.get_width() / 2., height),  # Posición del texto (centrado horizontalmente)
                    ha='center', va='center',  # Alineación horizontal y vertical
                    xytext=(0, 20),  # Desplazamiento vertical para que quede bien arriba de la barra
                    textcoords='offset points', rotation=90)  # Rotación vertical del texto

# Ajustar el diseño del gráfico para evitar cortes
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
features_to_use = feature_importance['Feature'][:-1]  # Mantener solo las características más importantes
X_train_reduced = X_train[features_to_use]
X_test_reduced = X_test[features_to_use]

# Reentrenar el modelo con las características seleccionadas
decision_tree_model.fit(X_train_reduced, y_train)
y_pred_reduced = decision_tree_model.predict(X_test_reduced)
accuracy_reduced_features = accuracy_score(y_test, y_pred_reduced)

print(f"Precisión con características seleccionadas: {accuracy_reduced_features:.5f}")
print("Informe de clasificación:")
print(classification_report(y_test, y_pred_reduced))
# Out:
# Precisión con características seleccionadas: 0.86087
# Informe de clasificación:
#               precision    recall  f1-score   support
#
#            1       0.40      0.67      0.50         3
#            2       1.00      1.00      1.00         8
#            3       0.58      0.47      0.52        15
#            4       0.99      0.97      0.98        71
#            5       0.00      0.00      0.00         5
#            6       1.00      1.00      1.00         5
#            7       1.00      1.00      1.00         5
#            8       0.75      1.00      0.86         3
#
#     accuracy                           0.86       115
#    macro avg       0.71      0.76      0.73       115
# weighted avg       0.87      0.86      0.86       115

# %% [markdown]
# #### ELIMINANDO LA VARIABLE 'avg_salary', disminuye la precisión de nuestro modelo.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Seleccionar solo las columnas numéricas
columnas_numericas = jb_encoded.select_dtypes(include=['number'])

# Calcular la matriz de correlaciones
matriz_correlaciones = columnas_numericas.corr()

# Crear un mapa de calor de la matriz de correlaciones
plt.figure(figsize=(12, 10))
sns.heatmap(matriz_correlaciones, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Matriz de Correlaciones')
plt.show()

# %% [markdown]
# Al Size y Evenue tener un correlación de 0,71, eliminaremos Size que tiene menos importancia en el modelo para evaluar resultados.

# %%
#Dividimos le set de daatos en entrenamiento y prueba
Xnew = jb_encoded.drop(columns=['job_desc','Size'])
ynew = jb_encoded['job_desc']

# %%
# Dividir los datos en conjuntos de entrenamiento y prueba (por ejemplo, 80/20)
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(Xnew, ynew, test_size=0.2, random_state=17)
print(X_train_new.shape, X_test_new.shape, y_train_new.shape, y_test_new.shape)
# Out:
# (457, 13) (115, 13) (457,) (115,)

# %%
# Ajustar el modelo a los datos de entrenamiento
decision_tree_model.fit(X_train_new, y_train_new)
# Out:
# DecisionTreeClassifier(random_state=17)

# %%
# Predecir las etiquetas en el conjunto de prueba
y_pred_new = decision_tree_model.predict(X_test_new)

# Calcular y mostrar la matriz de confusión
conf_matrix = plot_confusion_matrix(y_test_new, y_pred_new)
print("Matriz de confusión:")
print(conf_matrix)

# Calcular y mostrar la puntuación de precisión
accuracy = accuracy_score(y_test_new, y_pred_new)
print(f"Precisión del modelo: {accuracy}")

# Imprimir un informe de clasificación detallado
print("Informe de clasificación:")
print(classification_report(y_test_new, y_pred_new))
# Out:
# Matriz de confusión:
# None
# Precisión del modelo: 0.8869565217391304
# Informe de clasificación:
#               precision    recall  f1-score   support
#
#            1       0.33      0.67      0.44         3
#            2       1.00      1.00      1.00         8
#            3       0.67      0.67      0.67        15
#            4       0.99      0.97      0.98        71
#            5       0.00      0.00      0.00         5
#            6       1.00      1.00      1.00         5
#            7       1.00      1.00      1.00         5
#            8       0.75      1.00      0.86         3
#
#     accuracy                           0.89       115
#    macro avg       0.72      0.79      0.74       115
# weighted avg       0.88      0.89      0.88       115

# %%
# Obtener la importancia de las características
importances = decision_tree_model.feature_importances_

# Crear un DataFrame para visualizar la importancia de las características
feature_importance = pd.DataFrame({
    'Feature': Xnew.columns,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Mostrar la importancia de las características
print(feature_importance)
# Out:
#               Feature  Importance
# 7              Hadoop    0.322280
# 6               Excel    0.203390
# 10           BI Tools    0.174650
# 5              Python    0.091307
# 9                 AWS    0.044856
# 1              Sector    0.034132
# 12                Git    0.031011
# 2             Revenue    0.028509
# 11                SQL    0.026864
# 8               Spark    0.019317
# 0   Type of ownership    0.013252
# 4         company_age    0.010431
# 3          avg_salary    0.000000
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# Si quito 'Size', mejora la importancia del resto de variables pero mi modelo se mantiene exactamente igual.

# %% [markdown]
# 1. Precisión General del Modelo
# Precisión del Modelo: 0.887 (aproximadamente 88.7%)
#
# Esta es la proporción de predicciones correctas realizadas por el modelo en comparación con el total de predicciones. En este caso, el modelo acierta el 88.7% de las veces en el conjunto de datos de prueba.
#
# 2. Informe de Clasificación
# El informe de clasificación proporciona métricas detalladas para cada clase en el conjunto de datos. Aquí está la interpretación de las métricas clave:
#
# Precision (Precisión): La proporción de verdaderos positivos entre el total de predicciones positivas realizadas para una clase. Mide cuántas de las predicciones del modelo para una clase específica son correctas.
#
# Recall (Recuperación o Sensibilidad): La proporción de verdaderos positivos entre el total de casos reales positivos para una clase. Mide qué tan bien el modelo encuentra todos los casos de una clase específica.
#
# F1-Score: La media armónica de la precisión y el recall. Es útil cuando hay un desbalance en las clases, ya que considera tanto la precisión como el recall en un solo número.
#
# Support (Soporte): La cantidad de verdaderos casos de esa clase en el conjunto de datos de prueba. Esto te da una idea del tamaño de la clase.
#
# Detalles de las Clases
# Clase 1:
#
# Precisión: 0.33 (33% de las predicciones para la clase 1 son correctas)
# Recall: 0.67 (El modelo encuentra el 67% de los casos reales de la clase 1)
# F1-Score: 0.44 (Una combinación de precisión y recall para la clase 1)
# Soporte: 3 (Hay 3 instancias de la clase 1 en el conjunto de datos)
# Clase 2:
#
# Precisión: 1.00 (100% de las predicciones para la clase 2 son correctas)
# Recall: 1.00 (El modelo encuentra el 100% de los casos reales de la clase 2)
# F1-Score: 1.00 (Perfecto en precisión y recall para la clase 2)
# Soporte: 8 (Hay 8 instancias de la clase 2 en el conjunto de datos)
# Clase 3:
#
# Precisión: 0.67
# Recall: 0.67
# F1-Score: 0.67
# Soporte: 15
# Clase 4:
#
# Precisión: 0.99
# Recall: 0.97
# F1-Score: 0.98
# Soporte: 71
# Clase 5:
#
# Precisión: 0.00 (El modelo no predice correctamente la clase 5)
# Recall: 0.00 (El modelo no encuentra ningún caso real de la clase 5)
# F1-Score: 0.00
# Soporte: 5
# Clase 6:
#
# Precisión: 1.00
# Recall: 1.00
# F1-Score: 1.00
# Soporte: 5
# Clase 7:
#
# Precisión: 1.00
# Recall: 1.00
# F1-Score: 1.00
# Soporte: 5
# Clase 8:
#
# Precisión: 0.75
# Recall: 1.00
# F1-Score: 0.86
# Soporte: 3
# Promedios
# Macro Avg (Promedio Macro):
#
# Precisión: 0.72
# Recall: 0.79
# F1-Score: 0.74
# Estos valores son promedios no ponderados de las métricas para cada clase. Calculan el rendimiento del modelo de manera equilibrada sin tener en cuenta el número de instancias de cada clase.
#
# Weighted Avg (Promedio Ponderado):
#
# Precisión: 0.88
# Recall: 0.89
# F1-Score: 0.88
# Estos valores son promedios ponderados por el número de instancias de cada clase. Son útiles para ver cómo el modelo se desempeña en el conjunto de datos completo, teniendo en cuenta la frecuencia de cada clase.
#
# Conclusiones y Recomendaciones
# Desbalance de Clases: Tu modelo parece tener problemas con algunas clases específicas (por ejemplo, la clase 5) y está funcionando excepcionalmente bien con otras (por ejemplo, la clase 2 y la clase 6). Esto podría indicar un desbalance en el conjunto de datos o que algunas clases tienen características muy distintas de las demás.
#
# Mejora del Modelo:
#
# Revisar Datos: Asegúrate de que no haya problemas en los datos, como errores de etiquetado o falta de representación de ciertas clases.
# Ajustar Hiperparámetros: Experimenta con diferentes hiperparámetros y técnicas de preprocesamiento.
# Reevaluar Características: Realiza un análisis más detallado de la importancia de las características y considera la eliminación o adición de variables.
# Rebalanceo de Clases: Considera técnicas como el sobremuestreo de las clases minoritarias (SMOTE) o el submuestreo de las clases mayoritarias.
# Estas acciones te permitirán mejorar la capacidad del modelo para clasificar todas las clases de manera más equitativa y mejorar el rendimiento general.

# %% [markdown]
# #### LAS CLASES CON MÁS CONFUSIÓN SON ML ENGINEER Y DATA ENGINEER.

# %% [markdown]
# Pasos para la Selección de Modelo
# Entrenar Múltiples Clasificadores: Comienza entrenando cada modelo candidato en el mismo conjunto de datos de entrenamiento. Esto asegura que cada modelo aprenda de la misma información.
# Evaluación en el Conjunto de Pruebas: A continuación, evalúa el rendimiento de cada modelo en un conjunto de pruebas separado. Este conjunto de pruebas no debe haber sido visto por los modelos durante el entrenamiento, asegurando que nuestra evaluación refleje la capacidad de cada modelo para generalizar.
# Comparar Tasas de Error: Calcula la tasa de error (u otra métrica de rendimiento relevante) para cada modelo en el conjunto de pruebas. La tasa de error nos da una medida cuantitativa de cuán a menudo el modelo realiza predicciones incorrectas.
# Seleccionar el Mejor Modelo: Finalmente, selecciona el modelo con la menor tasa de error en el conjunto de pruebas. Este modelo es considerado el "mejor" entre los candidatos para nuestra aplicación específica.

# %% [markdown]
# #### VALIDACIÓN CRUZADA

# %% [markdown]
# #### REGRESIÓN LOGÍSTICA
